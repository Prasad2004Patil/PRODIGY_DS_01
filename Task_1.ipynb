# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('Task-1.csv')

# %%
df
# Out:
#                       Area_Name  Year           Group_Name  \
# 0     Andaman & Nicobar Islands  2001  Burglary - Property
# 1                Andhra Pradesh  2001  Burglary - Property
# 2             Arunachal Pradesh  2001  Burglary - Property
# 3                         Assam  2001  Burglary - Property
# 4                         Bihar  2001  Burglary - Property
# ...                         ...   ...                  ...
# 2444                 Tamil Nadu  2010       Total Property
# 2445                    Tripura  2010       Total Property
# 2446              Uttar Pradesh  2010       Total Property
# 2447                Uttarakhand  2010       Total Property
# 2448                West Bengal  2010       Total Property
#
#                             Sub_Group_Name  Cases_Property_Recovered  \
# 0                              3. Burglary                        27
# 1                              3. Burglary                      3321
# ...

# %%
df.head()
# Out:
#                    Area_Name  Year           Group_Name Sub_Group_Name  \
# 0  Andaman & Nicobar Islands  2001  Burglary - Property    3. Burglary
# 1             Andhra Pradesh  2001  Burglary - Property    3. Burglary
# 2          Arunachal Pradesh  2001  Burglary - Property    3. Burglary
# 3                      Assam  2001  Burglary - Property    3. Burglary
# 4                      Bihar  2001  Burglary - Property    3. Burglary
#
#    Cases_Property_Recovered  Cases_Property_Stolen  \
# 0                        27                     64
# 1                      3321                   7134
# 2                        66                    248
# 3                       539                   2423
# 4                       367                   3231
#
#    Value_of_Property_Recovered  Value_of_Property_Stolen
# 0                       755858                   1321961
# 1                     51483437                 147019348
# ...

# %%
df.tail()
# Out:
#           Area_Name  Year      Group_Name  \
# 2444     Tamil Nadu  2010  Total Property
# 2445        Tripura  2010  Total Property
# 2446  Uttar Pradesh  2010  Total Property
# 2447    Uttarakhand  2010  Total Property
# 2448    West Bengal  2010  Total Property
#
#                             Sub_Group_Name  Cases_Property_Recovered  \
# 2444  7. Total Property Stolen & Recovered                     16125
# 2445  7. Total Property Stolen & Recovered                       192
# 2446  7. Total Property Stolen & Recovered                      9130
# 2447  7. Total Property Stolen & Recovered                       964
# 2448  7. Total Property Stolen & Recovered                      4548
#
#       Cases_Property_Stolen  Value_of_Property_Recovered  \
# 2444                  21509                    660311804
# 2445                    879                      5666102
# 2446                  35068                    577591772
# 2447                   2234                     47135685
# ...

# %%
df.shape
# Out:
# (2449, 8)

# %%
df.columns
# Out:
# Index(['Area_Name', 'Year', 'Group_Name', 'Sub_Group_Name',
#        'Cases_Property_Recovered', 'Cases_Property_Stolen',
#        'Value_of_Property_Recovered', 'Value_of_Property_Stolen'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Area_Name                      object
# Year                            int64
# Group_Name                     object
# Sub_Group_Name                 object
# Cases_Property_Recovered        int64
# Cases_Property_Stolen           int64
# Value_of_Property_Recovered     int64
# Value_of_Property_Stolen        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2449 entries, 0 to 2448
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Area_Name                    2449 non-null   object
#  1   Year                         2449 non-null   int64
#  2   Group_Name                   2449 non-null   object
#  3   Sub_Group_Name               2449 non-null   object
#  4   Cases_Property_Recovered     2449 non-null   int64
#  5   Cases_Property_Stolen        2449 non-null   int64
#  6   Value_of_Property_Recovered  2449 non-null   int64
#  7   Value_of_Property_Stolen     2449 non-null   int64
# dtypes: int64(5), object(3)
# memory usage: 153.2+ KB

# %%
df.describe()
# Out:
#               Year  Cases_Property_Recovered  Cases_Property_Stolen  \
# count  2449.000000               2449.000000            2449.000000
# mean   2005.499388               1232.892201            3419.420988
# std       2.873294               3079.573907            8136.256820
# min    2001.000000                  0.000000               0.000000
# 25%    2003.000000                 13.000000              45.000000
# 50%    2005.000000                113.000000             358.000000
# 75%    2008.000000                722.000000            1875.000000
# max    2010.000000              27960.000000           80663.000000
#
#        Value_of_Property_Recovered  Value_of_Property_Stolen
# count                 2.449000e+03              2.449000e+03
# mean                  5.859924e+07              2.465431e+08
# std                   2.494403e+08              9.670035e+08
# min                   0.000000e+00              0.000000e+00
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum().any()
# Out:
# np.False_

# %%
df = df. fillna (method= "ffill")
df. head()
# Out:
# /var/folders/js/r7lkd0ys51jcsrkw3gf66m_40000gn/T/ipykernel_1531/4078639532.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df. fillna (method= "ffill")
#                    Area_Name  Year           Group_Name Sub_Group_Name  \
# 0  Andaman & Nicobar Islands  2001  Burglary - Property    3. Burglary
# 1             Andhra Pradesh  2001  Burglary - Property    3. Burglary
# 2          Arunachal Pradesh  2001  Burglary - Property    3. Burglary
# 3                      Assam  2001  Burglary - Property    3. Burglary
# 4                      Bihar  2001  Burglary - Property    3. Burglary
#
#    Cases_Property_Recovered  Cases_Property_Stolen  \
# 0                        27                     64
# 1                      3321                   7134
# 2                        66                    248
# 3                       539                   2423
# ...

# %%
df.isna().sum().any()
# Out:
# np.False_

# %%
df['Area_Name'].unique()
# Out:
# array(['Andaman & Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra & Nagar Haveli', 'Daman & Diu', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal'], dtype=object)

# %%
df['Year'].unique()
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010])

# %%
df['Group_Name'].unique()
# Out:
# array(['Burglary - Property', 'Criminal Breach of Trust - Property',
#        'Dacoity -Property', 'Other heads of Property',
#        'Robbery - Property', 'Theft - Property', 'Total Property'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['Area_Name', 'Year', 'Group_Name', 'Sub_Group_Name',
#        'Cases_Property_Recovered', 'Cases_Property_Stolen',
#        'Value_of_Property_Recovered', 'Value_of_Property_Stolen'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
numeric_columns = [
    "Cases_Property_Recovered",
    "Cases_Property_Stolen",
    "Value_of_Property_Recovered",
    "Value_of_Property_Stolen"
]
for col in numeric_columns:
    plt.figure(figsize=(5, 5))
    plt.hist(df[col], color='#B22222', bins=10)
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.title(f"Histogram of {col}")
    plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Convert non-numeric columns to appropriate types if necessary
# You can use this to convert all columns to numeric (forcing errors to NaN, so they won't affect the sum)
df = df.apply(pd.to_numeric, errors='coerce')

# Group the data by 'Year' and sum numeric columns
grouped_data = df.groupby("Year").sum()

# Total values per year (sum of all numeric columns)
total_values = grouped_data.sum(axis=1)

# Plot the data
plt.figure(figsize=(10, 7))  # Adjusted size for readability
plt.barh(total_values.index.astype(str), total_values.values, color='#191970')
plt.xlabel('Total Values', size=14)
plt.ylabel('Year', size=14)
plt.title('Total Values per Year', size=16)
plt.show()

# %%
country_by_1960 = df.sort_values(by='Value_of_Property_Recovered', ascending=False).head(20)
country_by_1960
# Out:
#       Area_Name  Year  Group_Name  Sub_Group_Name  Cases_Property_Recovered  \
# 2433        NaN  2010         NaN             NaN                     11549
# 1034        NaN  2010         NaN             NaN                        81
# 2434        NaN  2010         NaN             NaN                     27960
# 2329        NaN  2007         NaN             NaN                     25106
# 2399        NaN  2009         NaN             NaN                     26097
# 2364        NaN  2008         NaN             NaN                     26935
# 2155        NaN  2002         NaN             NaN                     19944
# 2448        NaN  2010         NaN             NaN                      4548
# 2376        NaN  2008         NaN             NaN                      9846
# 2295        NaN  2006         NaN             NaN                     24180
# 2307        NaN  2006         NaN             NaN                      8133
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv(r'Task-1.csv')

# Ensure the column you want to plot exists and replace 'Task-1' with the correct column name
column_name = 'Cases_Property_Stolen'  # Replace this with the actual column name from your dataset
if column_name in df.columns:
    # Create a histogram
    df[column_name].plot(kind='hist', bins=20, color='blue', edgecolor='black')
    plt.title('Distribution of Cases Property Stolen')
    plt.xlabel('Cases Stolen')
    plt.ylabel('Frequency')
    plt.show()
else:
    print(f"Column '{column_name}' not found in the dataset.")

# %%
import os
print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: /Users/Shared/Files From e.localized/CODES/PYTHON/PRODIGY_DS_01

# %%
df.head()
# Out:
#                    Area_Name  Year           Group_Name Sub_Group_Name  \
# 0  Andaman & Nicobar Islands  2001  Burglary - Property    3. Burglary
# 1             Andhra Pradesh  2001  Burglary - Property    3. Burglary
# 2          Arunachal Pradesh  2001  Burglary - Property    3. Burglary
# 3                      Assam  2001  Burglary - Property    3. Burglary
# 4                      Bihar  2001  Burglary - Property    3. Burglary
#
#    Cases_Property_Recovered  Cases_Property_Stolen  \
# 0                        27                     64
# 1                      3321                   7134
# 2                        66                    248
# 3                       539                   2423
# 4                       367                   3231
#
#    Value_of_Property_Recovered  Value_of_Property_Stolen
# 0                       755858                   1321961
# 1                     51483437                 147019348
# ...

# %%
file_path = 'Task-1.csv' 

if os.path.exists(file_path):
    data = pd.read_csv(file_path)
    print("File loaded successfully!")
else:
    print(f"File not found at: {file_path}")
# Out:
# File loaded successfully!

# %%
# Group by Area_Name and sum the cases
area_cases = data.groupby('Area_Name')['Cases_Property_Stolen'].sum()

# Create a bar chart
area_cases.plot(kind='bar', color='green')
plt.title('Total Cases Property Stolen by Area')
plt.xlabel('Area')
plt.ylabel('Total Cases Stolen')
plt.xticks(rotation=90)
plt.show()
